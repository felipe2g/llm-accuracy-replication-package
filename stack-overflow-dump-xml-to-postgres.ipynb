# %%
# %pip install lxml
# %pip install psycopg2-binary
# %pip install -qU langchain-google-genai
# %pip install python-dotenv
# %pip install langchain-core
# %pip install -qU langchain-openai
# %pip install pandas
# %pip install numpy
# %pip install sqlalchemy
# %pip install scipy
# %pip install matplotlib
# %pip install seaborn
# %pip install jsonlines
# %pip install bs4
# %pip install scikit-learn
# %pip install openpyxl

# %%
import time
from lxml import etree
import psycopg2
import xml.etree.ElementTree as ET
import random
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import PromptTemplate
from langchain_openai import ChatOpenAI
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns
import json
from bs4 import BeautifulSoup
from datetime import datetime
import os
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from scipy.stats import chisquare

# %%
# ===================================================
#      CONFIGURAÇÃO DO BANCO DE DADOS
# ===================================================
# Detalhes para a conexão com o banco de dados PostgreSQL
DB_NAME="dumpstack"
DB_USER="postgres"
DB_PASSWORD="postgres"
DB_HOST="localhost"
DB_PORT="5432"

# ===================================================
#          CONFIGURAÇÃO DE ARQUIVOS E DADOS
# ===================================================
# Caminho para o arquivo XML de entrada
XML_FILE_PATH="data/Posts.xml"


# ===================================================
#          REGRAS DE PROCESSAMENTO DE POSTS
# ===================================================
# Filtra por posts que são do tipo "Questão" (ID 1)
POST_TYPE_ID_TO_PROCESS=1

# Exige que a questão tenha um número mínimo de respostas
MINIMUM_ANSWER_COUNT=5

# Exige que a questão contenha uma tag específica (ex: 'java', 'python', etc.)
REQUIRED_TAG_IN_POST="java"

# Palavras que devem estar no "body" da pergunta
REQUIRED_KEYWORDS_IN_BODY=['<code>']

# Palavras que NÃO devem estar no "body" da pergunta
FORBIDDEN_KEYWORDS_IN_BODY=['<img>']

# %%
conn = psycopg2.connect(
    dbname=DB_NAME,
    user=DB_USER,
    password=DB_PASSWORD,
    host=DB_HOST,
    port=DB_PORT
)

cursor = conn.cursor()

engine = create_engine(f'postgresql://{DB_USER}:{DB_PASSWORD}@{DB_HOST}:{DB_PORT}/{DB_NAME}')

# %%
context = etree.iterparse(XML_FILE_PATH, events=('end',), tag='row')

# %%
def process_post_question_element(elem):
    """
    Processa o elemento XML e retorna uma tupla de dados ou None se for inválido.
    """
    try:
        post_type_id = int(elem.get('PostTypeId'))

        if post_type_id != POST_TYPE_ID_TO_PROCESS:
            return None

        accepted_answer_id = int(elem.get('AcceptedAnswerId')) if elem.get('AcceptedAnswerId') else None
        if accepted_answer_id is None:
            return None

        tags = elem.get('Tags').strip('|').split('|') if elem.get('Tags') else []
        if REQUIRED_TAG_IN_POST not in tags or not tags:
            return None

        answer_count = int(elem.get('AnswerCount')) if elem.get('AnswerCount') else None
        if answer_count is None or answer_count <= MINIMUM_ANSWER_COUNT:
            return None

        body = elem.get('Body')
        # Validação das palavras obrigatórias e proibidas
        body_lower = body.lower() if body else ""
        if any(word.lower() in body_lower for word in FORBIDDEN_KEYWORDS_IN_BODY):
            return None
        if not all(word.lower() in body_lower for word in REQUIRED_KEYWORDS_IN_BODY):
            return None

        post_id = int(elem.get('Id'))
        creation_date = elem.get('CreationDate')
        parent_id = int(elem.get('ParentId')) if elem.get('ParentId') else None
        score = int(elem.get('Score'))
        title = elem.get('Title')

        return (post_id, creation_date, parent_id, post_type_id, accepted_answer_id, score, body, title, tags, answer_count)
    except (AttributeError, ValueError, TypeError):
        return None

# %%
def insert_to_valid_posts_db(data, cursor, conn):
    if data:
        cursor.execute("SELECT 1 FROM posts WHERE post_id = %s", (data[0],))
        exists = cursor.fetchone()

        if exists:
            print(f"post_id {data[0]} já existe no banco de dados. Ignorando inserção.")
        else:
            cursor.execute(
                """
                INSERT INTO posts (post_id, creation_date, parent_id, post_type_id, accepted_answer_id, score, body, title, tags, answer_count)
                VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
                """,
                data
            )
            conn.commit()

# %%
for event, elem in context:
    result = process_post_question_element(elem)
    insert_to_valid_posts_db(result, cursor, conn)

    elem.clear()
    while elem.getprevious() is not None:
        del elem.getparent()[0]

# %% [markdown]
# ### Obtendo amostras analisáveis (5% de cada ano)

# %%
query = """
SELECT 
    post_id, 
    title,
    body, 
    EXTRACT(YEAR FROM creation_date)::integer AS year
FROM 
    posts
WHERE 
    body NOT ILIKE '%<img%' 
    AND body ILIKE '%<code>%'
"""

df = pd.read_sql(query, conn)

total_elements = len(df)
print(f"Total de elementos no DataFrame original: {total_elements}")

# Passo 2: Selecionando 5% de cada ano
sampled_parts = []
for year, part in df.groupby('year'):
    sampled_part = part.sample(frac=0.05)
    sampled_parts.append(sampled_part)
    print(f"Ano {year} - 5% amostrados: {len(sampled_part)} elementos")

# Passo 3: Combinando os resultados
final_sample = pd.concat(sampled_parts)

final_sample_elements = len(final_sample)
print(f"Total de elementos na amostra final: {final_sample_elements}")

# %%
def insert_to_answers_db(data, cursor, conn):
    if data:
        cursor.execute("SELECT 1 FROM posts WHERE post_id = %s", (data[0],))
        exists = cursor.fetchone()

        if exists:
            print(f"post_id {data[0]} já existe no banco de dados. Ignorando inserção.")
        else:
            cursor.execute(
                """
                INSERT INTO answers (post_id, post_type_id, parent_id, creation_date, score, body)
                VALUES (%s, %s, %s, %s, %s, %s)
                """,
                data
            )
            conn.commit()

# %%
def process_post_answer_element(elem):
    try:
        post_type_id = int(elem.get('PostTypeId')) if elem.get('PostTypeId') else None
        if post_type_id != 2:
            return None

        post_id = int(elem.get('Id')) if elem.get('Id') else None

        parent_id = int(elem.get('ParentId')) if elem.get('ParentId') else None

        creation_date = elem.get('CreationDate')

        score = int(elem.get('Score')) if elem.get('Score') else None

        body = elem.get('Body')

        if parent_id is None:
            return None

        return (post_id, post_type_id, parent_id, creation_date, score, body)

    except Exception as e:
        print(f"Erro ao processar o elemento: {e}")
        return None

# %%
for event, elem in context:
    result = process_post_answer_element(elem)
    insert_to_valid_posts_db(result, cursor, conn)

    # Limpar o elemento para liberar memória
    elem.clear()
    while elem.getprevious() is not None:
        del elem.getparent()[0]

# %%
query_delete_posts_without_answers = """
DELETE FROM posts
WHERE post_type_id = 1
  AND NOT EXISTS (
      SELECT 1
      FROM answers
      WHERE answers.parent_id = posts.post_id
  );
"""

cursor.execute(query_delete_posts_without_answers)
conn.commit()

# %%
query_posts = """
SELECT
    post_id,
    creation_date,
    accepted_answer_id,
    score,
    body,
    title,
    tags,
    answer_count
FROM
    posts
WHERE
    post_type_id = 1 -- Assumindo que post_type_id = 1 corresponde às perguntas
""" 

df_questions = pd.read_sql_query(query_posts, conn)

# %%
query_answers = """
SELECT
   post_id AS answer_id, -- Renomeia para evitar conflito de coluna com post_id da pergunta
   parent_id,
   creation_date AS answer_creation_date, -- Renomeia para evitar conflito de coluna
   score AS answer_score, -- Renomeia para evitar conflito de coluna
   body AS answer_body -- Renomeia para evitar conflito de coluna
FROM
   answers
WHERE
    post_type_id = 2 -- Assumindo que post_type_id = 2 corresponde às respostas
"""

df_answers = pd.read_sql_query(query_answers, conn)

# %%
grouped_answers = df_answers.groupby('parent_id')

def is_top_answer_also_accepted(question):
    question_id = question['post_id']
    accepted_id = question['accepted_answer_id']

    if pd.isna(accepted_id):
        return False

    if question_id not in grouped_answers.groups:
        return False

    answers = grouped_answers.get_group(question_id)
    top_answer = answers.loc[answers['answer_score'].idxmax()]
    return top_answer['answer_id'] == accepted_id

df_questions = df_questions[df_questions.apply(is_top_answer_also_accepted, axis=1)].copy()

# %%
def clean_html_except_code(html):
    soup = BeautifulSoup(html, "html.parser")
    for tag in soup.find_all(True):
        if tag.name == "a":
            href = tag.get("href", "")
            tag.replace_with(href)
        elif tag.name != "code":
            tag.unwrap()
    return str(soup).replace("\n", "")

# %%
def generate_prompt_for_question(question, df_answers):
    question_id = question['post_id']
    accepted_id = question['accepted_answer_id']

    answers = df_answers[df_answers['parent_id'] == question_id].copy()

    if len(answers) < 5:
        raise ValueError(f"Question {question_id} has fewer than 5 answers.")

    used_answer_ids = set()

    # Get accepted answer
    if accepted_id in answers['answer_id'].values:
        accepted_answer = answers[answers['answer_id'] == accepted_id].iloc[0]
        used_answer_ids.add(accepted_answer['answer_id'])
    else:
        raise ValueError(f"Question {question_id} has no valid accepted answer.")

    # Worst answer
    worst_answer = answers.sort_values(by='answer_score', ascending=True)
    worst_answer = worst_answer[~worst_answer['answer_id'].isin(used_answer_ids)].iloc[0]
    used_answer_ids.add(worst_answer['answer_id'])

    # Intermediate answer
    intermediate_candidates = answers[
        (~answers['answer_id'].isin(used_answer_ids)) &
        (answers['answer_score'] > 0)
    ].sort_values(by='answer_score')

    if intermediate_candidates.empty:
        intermediate_candidates = answers[~answers['answer_id'].isin(used_answer_ids)].sort_values(by='answer_score')
        if intermediate_candidates.empty:
            raise ValueError(f"Question {question_id} has no valid intermediate answer.")

    intermediate_answer = intermediate_candidates.iloc[len(intermediate_candidates) // 2]
    used_answer_ids.add(intermediate_answer['answer_id'])

    # Two random answers
    remaining_answers = answers[~answers['answer_id'].isin(used_answer_ids)]
    if len(remaining_answers) < 2:
        raise ValueError(f"Question {question_id} does not have enough answers for two random picks.")

    random_samples = remaining_answers.sample(n=2, random_state=random.randint(0, 9999))
    random_answer_1 = random_samples.iloc[0]
    random_answer_2 = random_samples.iloc[1]
    used_answer_ids.update([random_answer_1['answer_id'], random_answer_2['answer_id']])

    # Reorganize and shuffle for prompt
    selected_answers = [
        ("accepted", accepted_answer['answer_id'], accepted_answer['answer_body'], accepted_answer['answer_score'], accepted_answer['answer_creation_date']),
        ("worst", worst_answer['answer_id'], worst_answer['answer_body'], worst_answer['answer_score'], worst_answer['answer_creation_date']),
        ("intermediate", intermediate_answer['answer_id'], intermediate_answer['answer_body'], intermediate_answer['answer_score'], intermediate_answer['answer_creation_date']),
        ("random_1", random_answer_1['answer_id'], random_answer_1['answer_body'], random_answer_1['answer_score'], random_answer_1['answer_creation_date']),
        ("random_2", random_answer_2['answer_id'], random_answer_2['answer_body'], random_answer_2['answer_score'], random_answer_2['answer_creation_date'])
    ]

    random.shuffle(selected_answers)

    # Find the position (1-5) of the correct answer (accepted)
    correct_position = next(i + 1 for i, (label, aid, _, _, _) in enumerate(selected_answers) if label == "accepted")

    # Build answers string
    answers_text = "\n".join([
        f"Answer ID = {i+1}:\n{clean_html_except_code(body)}"
        for i, (_, _, body, _, _) in enumerate(selected_answers)
    ])

    question_body = clean_html_except_code(question['body'])

    prompt_json = {
        "custom_id": f"{question_id}",
        "method": "POST",
        "url": "/v1/chat/completions",
        "body": {
            "model": "gpt-4.1",
            "messages": [
                {
                    "role": "system",
                    "content": (
                        "You are a software engineer. Your task is to carefully read a Java "
                        "programming-related question and five possible answers and select the one that "
                        "most accurately addresses the question. Respond with only the ID of the most accurate answer."
                    )
                },
                {
                    "role": "user",
                    "content": (
                        f"You will receive the title, the question tags, and body of a Java program-ming question, followed by five possible answers. "
                        f"Your task is to identify which answer most accurately addresses the question. "
                        f"Return only the ID of that answer. No explanation, no formatting, and no additional text. \n"
                        f"Question Title: {question['title']}\n"
                        f"Question Tags: {', '.join(question['tags'])}\n"
                        f"Question: {question_body}\n\n"
                        f"{answers_text}\n\n"
                    )
                }
            ],
            "temperature": 0.0,
            "max_tokens": None
        }
    }

    # Structure for tracking
    answer_map = {}
    for i, (label, aid, body, score, date) in enumerate(selected_answers):
        answer_map[f"answer_{i+1}_id"] = aid
        answer_map[f"answer_{i+1}_body"] = body
        answer_map[f"answer_{i+1}_type"] = label
        answer_map[f"answer_{i+1}_score"] = score
        # Formatar data para dd/MM/yyyy
        formatted_date = pd.to_datetime(date, errors='coerce').strftime('%d/%m/%Y') if pd.notna(date) else None
        answer_map[f"answer_{i+1}_date"] = formatted_date

    return prompt_json, correct_position, answer_map

# %%
jsonl_data = []
csv_data_wide = []

timestamp = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
base_dir = os.path.join("data", timestamp)
os.makedirs(base_dir, exist_ok=True)

for i, (_, question) in enumerate(df_questions.iterrows()):
    try:
        prompt_json, correct_position, answer_map = generate_prompt_for_question(question, df_answers)
        jsonl_data.append(prompt_json)

        # Construir registro CSV
        csv_entry = {
            "creation_date": question['creation_date'],
            "question_id": question['post_id'],
            "question_title": question['title'],
            "question_body": question['body'],
            "correct_answer_position": correct_position
        }
        csv_entry.update(answer_map)
        csv_data_wide.append(csv_entry)

        # Salvar a cada 50 prompts
        if len(jsonl_data) == 50:
            part_num = i // 50 + 1
            jsonl_path = os.path.join(base_dir, f"output_part{part_num}.jsonl")
            with open(jsonl_path, "w", encoding="utf-8") as f_jsonl:
                for entry in jsonl_data:
                    f_jsonl.write(json.dumps(entry, ensure_ascii=False) + "\n")
            jsonl_data = []  # Limpar buffer

    except Exception as e:
        print(f"Error in question {question['post_id']}: {e}")

# Salvar qualquer sobra
if jsonl_data:
    part_num = (len(df_questions) - 1) // 50 + 1
    jsonl_path = os.path.join(base_dir, f"output_part{part_num}.jsonl")
    with open(jsonl_path, "w", encoding="utf-8") as f_jsonl:
        for entry in jsonl_data:
            f_jsonl.write(json.dumps(entry, ensure_ascii=False) + "\n")

# Salvar CSV final
csv_path = os.path.join(base_dir, "answers_wide.csv")
df_csv = pd.DataFrame(csv_data_wide)
df_csv.to_csv(csv_path, index=False, encoding="utf-8")

# %%
cursor.close()
conn.close()
